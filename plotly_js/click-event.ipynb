# %% [markdown]
# https://plot.ly/python/click-events/
#
# see `plotly_click_events.html` on how i handled the javascript part

# %%
import plotly.plotly as py
import cufflinks as cf
import pandas as pd

cf.set_config_file(offline=False, world_readable=True, theme='ggplot')

df = pd.read_csv('http://www.stat.ubc.ca/~jenny/notOcto/STAT545A/examples/gapminder/data/gapminderDataFiveYear.txt', sep='\t')
df2007 = df[df.year==2007]
df1952 = df[df.year==1952]
df.head(2)

df2007['lifeExp'] *= 10 # to distinguish from the demo
df2007.iplot(kind='scatter', mode='markers', x='gdpPercap', y='lifeExp', filename='cufflinks/simple-scatter')
# Out:
# /home/takanori/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~takanori/89.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# https://plot.ly/~takanori/89/lifeexp/

# %%
df2007
# Out:
#                        country  year         pop continent  lifeExp  \
# 11                 Afghanistan  2007  3.1890e+07      Asia   438.28
# 23                     Albania  2007  3.6005e+06    Europe   764.23
# 35                     Algeria  2007  3.3333e+07    Africa   723.01
# 47                      Angola  2007  1.2420e+07    Africa   427.31
# 59                   Argentina  2007  4.0302e+07  Americas   753.20
# 71                   Australia  2007  2.0434e+07   Oceania   812.35
# 83                     Austria  2007  8.1998e+06    Europe   798.29
# 95                     Bahrain  2007  7.0857e+05      Asia   756.35
# 107                 Bangladesh  2007  1.5045e+08      Asia   640.62
# 119                    Belgium  2007  1.0392e+07    Europe   794.41
# 131                      Benin  2007  8.0783e+06    Africa   567.28
# 143                    Bolivia  2007  9.1192e+06  Americas   655.54
# 155     Bosnia and Herzegovina  2007  4.5522e+06    Europe   748.52
# ...
