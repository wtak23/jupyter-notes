# %% [markdown]
# https://plot.ly/python/ipython-notebook-tutorial/
#
# I only took relevant portion out of above.
#
#   **Table of Contents**
#
#   <div id="toc"></div>
#   <script type="text/javascript"
#   src="https://raw.github.com/kmahelona/ipython_notebook_goodies/master/ipython_notebook_toc.js">
#   </script>

# %% [markdown]
# # MPL to Plotly

# %% [markdown]
# ## First MPL

# %%
fig1 = plt.figure()
# Make a legend for specific lines.
import matplotlib.pyplot as plt
import numpy as np


t1 = np.arange(0.0, 2.0, 0.1)
t2 = np.arange(0.0, 2.0, 0.01)

# note that plot returns a list of lines.  The "l1, = plot" usage
# extracts the first element of the list into l1 using tuple
# unpacking.  So l1 is a Line2D instance, not a sequence of lines
l1, = plt.plot(t2, np.exp(-t2))
l2, l3 = plt.plot(t2, np.sin(2 * np.pi * t2), '--go', t1, np.log(1 + t1), '.')
l4, = plt.plot(t2, np.exp(-t2) * np.sin(2 * np.pi * t2), 'rs-.')

plt.xlabel('time')
plt.ylabel('volts')
plt.title('Damped oscillation')

plt.show()

# %%
py.iplot_mpl(fig1, strip_style = True)
# Out:
# /home/takanori/.local/lib/python2.7/site-packages/plotly/matplotlylib/renderer.py:516: UserWarning:
#
# Looks like the annotation(s) you are trying
# to draw lies/lay outside the given figure size.
#
# Therefore, the resulting Plotly figure may not be
# large enough to view the full text. To adjust
# the size of the figure, use the 'width' and
# 'height' keys in the Layout object. Alternatively,
# use the Margin object to adjust the figure's margins.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~takanori/534.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Now plotly

# %% [markdown]
# # Plotting with Seaborn

# %%
import matplotlib.pyplot as plt
import plotly.plotly as py
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import seaborn as sns

fig16 = plt.figure()

sns.set_palette("hls")
mpl.rc("figure", figsize=(8, 4))
data = randn(200)
sns.distplot(data);

py.iplot_mpl(fig16, strip_style = True)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~takanori/532.embed" height="525px" width="100%"></iframe>
